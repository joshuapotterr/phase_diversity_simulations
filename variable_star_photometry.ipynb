# %%
bias_files=[f"d{n}.fits" for n in range(114,122)]
sky_flat_v=[f"d{n}.fits" for n in range(129,131)]
cal2_files=[f"d{n}.fits" for n in range(154, 157)]
ah_leo_1=[f"d{n}.fits" for n in range(159, 162)]
ah_leo_2=[f"d{n}.fits" for n in range(199, 202)]
ah_leo_3=[f"d{n}.fits" for n in range(224, 227)]
ah_leo_3=[f"d{n}.fits" for n in range(244, 247)]
